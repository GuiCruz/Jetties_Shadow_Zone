# %%
import numpy as np
import datetime
import matplotlib.pyplot as plt
import pickle
import pyproj
from pyproj import Proj, transform
import rasterio
from rasterio.plot import show
import matplotlib.colors as colors
from scipy.signal import find_peaks

# %%
roots = "C:\\Users\\simcosta\\Documents\\doc\\Campo_2023\\Campo_2023\\Processados\\"
file_names = ['dados_gps.pkl', 'dados_ctd.pkl']

# Dicionário para armazenar os dados já processados de velocidadee outros
data = {}

# Loop através dos nomes dos arquivos e carrega os dados usando pickle
for file_name in file_names:
    with open(roots+file_name, 'rb') as file:
        data[file_name.replace('.pkl', '')] = pickle.load(file)

# %%
fp ='C:\\Users\\simcosta\\Documents\\doc\\Campo_2023\\Campo_2023\\dados_brutos\\2023-11-23-00_00_2023-11-23-23_59_Sentinel-2_L2A_Highlight_Optimized_Natural_Color.tiff'
img = rasterio.open(fp)
red_band = img.read(3) 
green_band = img.read(2)
blue_band = img.read(1)

# Reorganiza as bandas para RGB
rgb_img = np.stack([red_band, green_band, blue_band], axis=-1)

fig, ax = plt.subplots(figsize=(6, 6), dpi=200)

# Exibir a imagem rasterio
ax.imshow(rgb_img, extent=[img.bounds.left, img.bounds.right, img.bounds.bottom, img.bounds.top])
ax.scatter(data['dados_gps'][:][1], data['dados_gps'][:][2], s=0.5, color ='r')
ax.set_xlim([-52.15, -52.08])
ax.set_ylim([-32.21, -32.15])
ax.axis('off')

# %%
myProj = Proj('+proj=utm +zone=22 +south +datum=WGS84 +units=m +no_defs')

lon0 = np.interp(data['dados_ctd'][21][0][:], data['dados_gps'][0][:], data['dados_gps'][1][:])
lat0 = np.interp(data['dados_ctd'][21][0][:], data['dados_gps'][0][:], data['dados_gps'][2][:])

fig, ax = plt.subplots(figsize=(6, 6), dpi=200)

# Exibir a imagem rasterio
ax.imshow(rgb_img, extent=[img.bounds.left, img.bounds.right, img.bounds.bottom, img.bounds.top])
ax.scatter(lon0, lat0, color = 'k')
ax.scatter(data['dados_gps'][:][1], data['dados_gps'][:][2], s=0.5, color ='r')
ax.set_xlim([-52.15, -52.08])
ax.set_ylim([-32.21, -32.15])
ax.axis('off')

# %%
sua_serie_de_dados = np.array(data['dados_ctd'][21][1][:])

# Define um valor limite
limite = 1.1

# Encontre os picos na série de dados
derivada = np.diff(sua_serie_de_dados)
mudanca_sinal = derivada[:-1] * derivada[1:]
pontos_de_mudanca = np.where((mudanca_sinal < 0) & (sua_serie_de_dados[:-2] < limite))[0] + 1
pontos_de_mudanca

# %%
np.shape(data['dados_ctd'][21][1][:])

# %%
fig, ax = plt.subplots(figsize=(16, 5), dpi=100)

ax.plot(data['dados_ctd'][21][0][:], data['dados_ctd'][21][1][:], 'k')
ax.plot(data['dados_ctd'][21][0][0:63], data['dados_ctd'][21][1][0:63])
ax.plot(data['dados_ctd'][21][0][154:224], data['dados_ctd'][21][1][154:224])
ax.plot(data['dados_ctd'][21][0][324:390], data['dados_ctd'][21][1][324:390])
ax.plot(data['dados_ctd'][21][0][472:532], data['dados_ctd'][21][1][472:532])
ax.plot(data['dados_ctd'][21][0][637:694], data['dados_ctd'][21][1][637:694])
ax.plot(data['dados_ctd'][21][0][799:855], data['dados_ctd'][21][1][799:855])
ax.plot(data['dados_ctd'][21][0][943:1000], data['dados_ctd'][21][1][943:1000])
ax.plot(data['dados_ctd'][21][0][1094:1147], data['dados_ctd'][21][1][1094:1147])
ax.plot(data['dados_ctd'][21][0][1241:1287], data['dados_ctd'][21][1][1241:1287])
ax.plot(data['dados_ctd'][21][0][1357:1388], data['dados_ctd'][21][1][1357:1388])
ax.plot(data['dados_ctd'][21][0][1444:1469], data['dados_ctd'][21][1][1444:1469])
ax.plot(data['dados_ctd'][21][0][1510:1540], data['dados_ctd'][21][1][1510:1540])

# %%
z_norm = np.arange(0.3,8.55,0.05)
sal_norm = np.zeros((12,165))
turb_norm = np.zeros((12,165))
cla_norm = np.zeros((12,165))
od_norm = np.zeros((12,165))
temp_norm = np.zeros((12,165))
dens_norm = np.zeros((12,165))

time_norm = []
time_norm.append(np.mean(data['dados_ctd'][21][0][0:63]))
time_norm.append(np.mean(data['dados_ctd'][21][0][154:224]))
time_norm.append(np.mean(data['dados_ctd'][21][0][324:390]))
time_norm.append(np.mean(data['dados_ctd'][21][0][472:532]))
time_norm.append(np.mean(data['dados_ctd'][21][0][637:694]))
time_norm.append(np.mean(data['dados_ctd'][21][0][799:855]))
time_norm.append(np.mean(data['dados_ctd'][21][0][943:1000]))
time_norm.append(np.mean(data['dados_ctd'][21][0][1094:1147]))
time_norm.append(np.mean(data['dados_ctd'][21][0][1241:1287]))
time_norm.append(np.mean(data['dados_ctd'][21][0][1357:1388]))
time_norm.append(np.mean(data['dados_ctd'][21][0][1444:1469]))
time_norm.append(np.mean(data['dados_ctd'][21][0][1510:1540]))

# %%
myProj = Proj('+proj=utm +zone=22 +south +datum=WGS84 +units=m +no_defs')
ctd_loc =  np.zeros((12, 2))

fig, ax = plt.subplots(figsize=(6, 6), dpi=100)

for i in range(0,12):
    lon0 = np.interp(time_norm[i], data['dados_gps'][0][:], data['dados_gps'][1][:])
    lat0 = np.interp(time_norm[i], data['dados_gps'][0][:], data['dados_gps'][2][:])
    ctd_loc[i,0],ctd_loc[i,1] = myProj(lon0, lat0) 
    ax.scatter(ctd_loc[i,1], ctd_loc[i,0], color = 'r')


ctd_dist = np.sqrt((ctd_loc[1:,0] - ctd_loc[:-1,0])**2 + (ctd_loc[1:,1] - ctd_loc[:-1,1])**2)
ctd_cumdist = np.cumsum(ctd_dist)
ctd_cumdist = np.insert(ctd_cumdist, 0, 0)


P1_utm_E_init = 396102.197559
P1_utm_N_init = 6439967.08943

P2_utm_E_init = 395259.915163
P2_utm_N_init = 6439348.88736

P3_utm_E_init = 393947.507994
P3_utm_N_init = 6438615.82996

P4_utm_E_init = 393106.974459
P4_utm_N_init = 6437854.43456


ax.plot(P4_utm_N_init, P4_utm_E_init, '.', color ='k')
ax.scatter(ctd_loc[4,1], ctd_loc[4,0], color = 'k')
print(datetime.datetime.fromtimestamp(time_norm[4]))

# %%
# print(np.nanmax(data['dados_ctd'][21][1][]),z_norm[16])

trash1 = np.interp(z_norm, data['dados_ctd'][21][1][0:63], data['dados_ctd'][21][3][0:63])
trash2 = np.interp(z_norm, data['dados_ctd'][21][1][0:63], data['dados_ctd'][21][5][0:63])
trash3 = np.interp(z_norm, data['dados_ctd'][21][1][0:63], data['dados_ctd'][21][4][0:63])
trash4 = np.interp(z_norm, data['dados_ctd'][21][1][0:63], data['dados_ctd'][21][6][0:63])
trash5 = np.interp(z_norm, data['dados_ctd'][21][1][0:63], data['dados_ctd'][21][2][0:63])
trash6 = np.interp(z_norm, data['dados_ctd'][21][1][0:63], data['dados_ctd'][21][7][0:63])


trash1[124:] = np.nan
trash2[124:] = np.nan
trash3[124:] = np.nan
trash4[124:] = np.nan
trash5[124:] = np.nan
trash6[124:] = np.nan

plt.title('profile 1')
plt.plot( data['dados_ctd'][21][5][0:63], data['dados_ctd'][21][1][0:63], 'r')
plt.plot( data['dados_ctd'][21][5][0:134], data['dados_ctd'][21][1][0:134], 'k', ls = '--', lw = 1)
plt.plot(trash2,z_norm, 'b')



sal_norm[0][:] = trash1
turb_norm[0][:] = trash2
cla_norm[0][:] = trash3
od_norm[0][:] = trash4
temp_norm[0][:] = trash5
dens_norm[0][:] = trash6

# %%
# print(np.nanmax(data['dados_ctd'][21][1][]),z_norm[16])

trash1 = np.interp(z_norm, data['dados_ctd'][21][1][154:224], data['dados_ctd'][21][3][154:224])
trash2 = np.interp(z_norm, data['dados_ctd'][21][1][154:224], data['dados_ctd'][21][5][154:224])
trash3 = np.interp(z_norm, data['dados_ctd'][21][1][154:224], data['dados_ctd'][21][4][154:224])
trash4 = np.interp(z_norm, data['dados_ctd'][21][1][154:224], data['dados_ctd'][21][6][154:224])
trash5 = np.interp(z_norm, data['dados_ctd'][21][1][154:224], data['dados_ctd'][21][2][154:224])
trash6 = np.interp(z_norm, data['dados_ctd'][21][1][154:224], data['dados_ctd'][21][7][154:224])


trash1[145:] = np.nan
trash2[145:] = np.nan
trash3[145:] = np.nan
trash4[145:] = np.nan
trash5[145:] = np.nan
trash6[145:] = np.nan

plt.title('profile 2')
plt.plot( data['dados_ctd'][21][5][154:224], data['dados_ctd'][21][1][154:224], 'r')
plt.plot( data['dados_ctd'][21][5][154:250], data['dados_ctd'][21][1][154:250], 'k', ls = '--', lw = 1)
plt.plot(trash2,z_norm, 'b')


sal_norm[1][:] = trash1
turb_norm[1][:] = trash2
cla_norm[1][:] = trash3
od_norm[1][:] = trash4
temp_norm[1][:] = trash5
dens_norm[1][:] = trash6

# %%
# print(np.nanmax(data['dados_ctd'][21][1][]),z_norm[16])

trash1 = np.interp(z_norm, data['dados_ctd'][21][1][324:390], data['dados_ctd'][21][3][324:390])
trash2 = np.interp(z_norm, data['dados_ctd'][21][1][324:390], data['dados_ctd'][21][5][324:390])
trash3 = np.interp(z_norm, data['dados_ctd'][21][1][324:390], data['dados_ctd'][21][4][324:390])
trash4 = np.interp(z_norm, data['dados_ctd'][21][1][324:390], data['dados_ctd'][21][6][324:390])
trash5 = np.interp(z_norm, data['dados_ctd'][21][1][324:390], data['dados_ctd'][21][2][324:390])
trash6 = np.interp(z_norm, data['dados_ctd'][21][1][324:390], data['dados_ctd'][21][7][324:390])



trash1[132:] = np.nan
trash2[132:] = np.nan
trash3[132:] = np.nan
trash4[132:] = np.nan
trash5[132:] = np.nan
trash6[132:] = np.nan

plt.title('profile 3')
plt.plot( data['dados_ctd'][21][5][324:390], data['dados_ctd'][21][1][324:390], 'r')
plt.plot( data['dados_ctd'][21][5][324:450], data['dados_ctd'][21][1][324:450], 'k', ls = '--', lw = 1)
plt.plot(trash2,z_norm, 'b')



sal_norm[2][:] = trash1
turb_norm[2][:] = trash2
cla_norm[2][:] = trash3
od_norm[2][:] = trash4
temp_norm[2][:] = trash5
dens_norm[2][:] = trash6

# %%
# print(np.nanmax(data['dados_ctd'][21][1][]),z_norm[16])

trash1 = np.interp(z_norm, data['dados_ctd'][21][1][472:532], data['dados_ctd'][21][3][472:532])
trash2 = np.interp(z_norm, data['dados_ctd'][21][1][472:532], data['dados_ctd'][21][5][472:532])
trash3 = np.interp(z_norm, data['dados_ctd'][21][1][472:532], data['dados_ctd'][21][4][472:532])
trash4 = np.interp(z_norm, data['dados_ctd'][21][1][472:532], data['dados_ctd'][21][6][472:532])
trash5 = np.interp(z_norm, data['dados_ctd'][21][1][472:532], data['dados_ctd'][21][2][472:532])
trash6 = np.interp(z_norm, data['dados_ctd'][21][1][472:532], data['dados_ctd'][21][7][472:532])

trash1[144:] = np.nan
trash2[144:] = np.nan
trash3[144:] = np.nan
trash4[144:] = np.nan
trash5[144:] = np.nan
trash6[144:] = np.nan

plt.title('profile 4')
plt.plot( data['dados_ctd'][21][5][472:532], data['dados_ctd'][21][1][472:532], 'r')
plt.plot( data['dados_ctd'][21][5][472:533], data['dados_ctd'][21][1][472:533], 'k', ls = '--', lw = 1)
plt.plot(trash2,z_norm, 'b')



sal_norm[3][:] = trash1
turb_norm[3][:] = trash2
cla_norm[3][:] = trash3
od_norm[3][:] = trash4
temp_norm[3][:] = trash5
dens_norm[3][:] = trash6

# %%
# print(np.nanmax(data['dados_ctd'][21][1][]),z_norm[16])

trash1 = np.interp(z_norm, data['dados_ctd'][21][1][637:694], data['dados_ctd'][21][3][637:694])
trash2 = np.interp(z_norm, data['dados_ctd'][21][1][637:694], data['dados_ctd'][21][5][637:694])
trash3 = np.interp(z_norm, data['dados_ctd'][21][1][637:694], data['dados_ctd'][21][4][637:694])
trash4 = np.interp(z_norm, data['dados_ctd'][21][1][637:694], data['dados_ctd'][21][6][637:694])
trash5 = np.interp(z_norm, data['dados_ctd'][21][1][637:694], data['dados_ctd'][21][2][637:694])
trash6 = np.interp(z_norm, data['dados_ctd'][21][1][637:694], data['dados_ctd'][21][7][637:694])


trash1[144:] = np.nan
trash2[144:] = np.nan
trash3[144:] = np.nan
trash4[144:] = np.nan
trash5[144:] = np.nan
trash6[144:] = np.nan

plt.title('profile 5')
plt.plot( data['dados_ctd'][21][5][637:694], data['dados_ctd'][21][1][637:694], 'r')
plt.plot( data['dados_ctd'][21][5][637:695], data['dados_ctd'][21][1][637:695], 'k', ls = '--', lw = 1)
plt.plot(trash2,z_norm, 'b')



sal_norm[4][:] = trash1
turb_norm[4][:] = trash2
cla_norm[4][:] = trash3
od_norm[4][:] = trash4
temp_norm[4][:] = trash5
dens_norm[4][:] = trash6

# %%
# print(np.nanmax(data['dados_ctd'][21][1][]),z_norm[16])

trash1 = np.interp(z_norm, data['dados_ctd'][21][1][799:855], data['dados_ctd'][21][3][799:855])
trash2 = np.interp(z_norm, data['dados_ctd'][21][1][799:855], data['dados_ctd'][21][5][799:855])
trash3 = np.interp(z_norm, data['dados_ctd'][21][1][799:855], data['dados_ctd'][21][4][799:855])
trash4 = np.interp(z_norm, data['dados_ctd'][21][1][799:855], data['dados_ctd'][21][6][799:855])
trash5 = np.interp(z_norm, data['dados_ctd'][21][1][799:855], data['dados_ctd'][21][2][799:855])
trash6 = np.interp(z_norm, data['dados_ctd'][21][1][799:855], data['dados_ctd'][21][7][799:855])


trash1[116:] = np.nan
trash2[116:] = np.nan
trash3[116:] = np.nan
trash4[116:] = np.nan
trash5[116:] = np.nan
trash6[116:] = np.nan

plt.title('profile 6')
plt.plot( data['dados_ctd'][21][5][799:855], data['dados_ctd'][21][1][799:855], 'r')
plt.plot( data['dados_ctd'][21][5][799:900], data['dados_ctd'][21][1][799:900], 'k', ls = '--', lw = 1)
plt.plot(trash2,z_norm, 'b')



sal_norm[5][:] = trash1
turb_norm[5][:] = trash2
cla_norm[5][:] = trash3
od_norm[5][:] = trash4
temp_norm[5][:] = trash5
dens_norm[5][:] = trash6

# %%
# print(np.nanmax(data['dados_ctd'][21][1][]),z_norm[16])

trash1 = np.interp(z_norm, data['dados_ctd'][21][1][943:1000], data['dados_ctd'][21][3][943:1000])
trash2 = np.interp(z_norm, data['dados_ctd'][21][1][943:1000], data['dados_ctd'][21][5][943:1000])
trash3 = np.interp(z_norm, data['dados_ctd'][21][1][943:1000], data['dados_ctd'][21][4][943:1000])
trash4 = np.interp(z_norm, data['dados_ctd'][21][1][943:1000], data['dados_ctd'][21][6][943:1000])
trash5 = np.interp(z_norm, data['dados_ctd'][21][1][943:1000], data['dados_ctd'][21][2][943:1000])
trash6 = np.interp(z_norm, data['dados_ctd'][21][1][943:1000], data['dados_ctd'][21][7][943:1000])


trash1[128:] = np.nan
trash2[128:] = np.nan
trash3[128:] = np.nan
trash4[128:] = np.nan
trash5[128:] = np.nan
trash6[128:] = np.nan

plt.title('profile 7')
plt.plot( data['dados_ctd'][21][5][943:1000], data['dados_ctd'][21][1][943:1000], 'r')
plt.plot( data['dados_ctd'][21][5][943:1010], data['dados_ctd'][21][1][943:1010], 'k', ls = '--', lw = 1)
plt.plot(trash2,z_norm, 'b')


sal_norm[6][:] = trash1
turb_norm[6][:] = trash2
cla_norm[6][:] = trash3
od_norm[6][:] = trash4
temp_norm[6][:] = trash5
dens_norm[6][:] = trash6

# %%
# print(np.nanmax(data['dados_ctd'][21][1][]),z_norm[16])

trash1 = np.interp(z_norm, data['dados_ctd'][21][1][1094:1147], data['dados_ctd'][21][3][1094:1147])
trash2 = np.interp(z_norm, data['dados_ctd'][21][1][1094:1147], data['dados_ctd'][21][5][1094:1147])
trash3 = np.interp(z_norm, data['dados_ctd'][21][1][1094:1147], data['dados_ctd'][21][4][1094:1147])
trash4 = np.interp(z_norm, data['dados_ctd'][21][1][1094:1147], data['dados_ctd'][21][6][1094:1147])
trash5 = np.interp(z_norm, data['dados_ctd'][21][1][1094:1147], data['dados_ctd'][21][2][1094:1147])
trash6 = np.interp(z_norm, data['dados_ctd'][21][1][1094:1147], data['dados_ctd'][21][7][1094:1147])

trash1[127:] = np.nan
trash2[127:] = np.nan
trash3[127:] = np.nan
trash4[127:] = np.nan
trash5[127:] = np.nan
trash6[127:] = np.nan

plt.title('profile 8')
plt.plot( data['dados_ctd'][21][5][1094:1147], data['dados_ctd'][21][1][1094:1147], 'r')
plt.plot( data['dados_ctd'][21][5][1094:1200], data['dados_ctd'][21][1][1094:1200], 'k', ls = '--', lw = 1)
plt.plot(trash2,z_norm, 'b')



sal_norm[7][:] = trash1
turb_norm[7][:] = trash2
cla_norm[7][:] = trash3
od_norm[7][:] = trash4
temp_norm[7][:] = trash5
dens_norm[7][:] = trash6

# %%
# print(np.nanmax(data['dados_ctd'][21][1][]),z_norm[16])

trash1 = np.interp(z_norm, data['dados_ctd'][21][1][1241:1287], data['dados_ctd'][21][3][1241:1287])
trash2 = np.interp(z_norm, data['dados_ctd'][21][1][1241:1287], data['dados_ctd'][21][5][1241:1287])
trash3 = np.interp(z_norm, data['dados_ctd'][21][1][1241:1287], data['dados_ctd'][21][4][1241:1287])
trash4 = np.interp(z_norm, data['dados_ctd'][21][1][1241:1287], data['dados_ctd'][21][6][1241:1287])
trash5 = np.interp(z_norm, data['dados_ctd'][21][1][1241:1287], data['dados_ctd'][21][2][1241:1287])
trash6 = np.interp(z_norm, data['dados_ctd'][21][1][1241:1287], data['dados_ctd'][21][7][1241:1287])


trash1[90:] = np.nan
trash2[90:] = np.nan
trash3[90:] = np.nan
trash4[90:] = np.nan
trash5[90:] = np.nan
trash6[90:] = np.nan

plt.title('profile 9')
plt.plot( data['dados_ctd'][21][5][1241:1287], data['dados_ctd'][21][1][1241:1287], 'r')
plt.plot( data['dados_ctd'][21][5][1241:1310], data['dados_ctd'][21][1][1241:1310], 'k', ls = '--', lw = 1)
plt.plot(trash2,z_norm, 'b')


sal_norm[8][:] = trash1
turb_norm[8][:] = trash2
cla_norm[8][:] = trash3
od_norm[8][:] = trash4
temp_norm[8][:] = trash5
dens_norm[8][:] = trash6

# %%
# print(np.nanmax(data['dados_ctd'][21][1][]),z_norm[16])

trash1 = np.interp(z_norm, data['dados_ctd'][21][1][1357:1388], data['dados_ctd'][21][3][1357:1388])
trash2 = np.interp(z_norm, data['dados_ctd'][21][1][1357:1388], data['dados_ctd'][21][5][1357:1388])
trash3 = np.interp(z_norm, data['dados_ctd'][21][1][1357:1388], data['dados_ctd'][21][4][1357:1388])
trash4 = np.interp(z_norm, data['dados_ctd'][21][1][1357:1388], data['dados_ctd'][21][6][1357:1388])
trash5 = np.interp(z_norm, data['dados_ctd'][21][1][1357:1388], data['dados_ctd'][21][2][1357:1388])
trash6 = np.interp(z_norm, data['dados_ctd'][21][1][1357:1388], data['dados_ctd'][21][7][1357:1388])


trash1[64:] = np.nan
trash2[64:] = np.nan
trash3[64:] = np.nan
trash4[64:] = np.nan
trash5[64:] = np.nan
trash6[64:] = np.nan

plt.title('profile 10')
plt.plot( data['dados_ctd'][21][5][1357:1388], data['dados_ctd'][21][1][1357:1388], 'r')
plt.plot( data['dados_ctd'][21][5][1357:1410], data['dados_ctd'][21][1][1357:1410], 'k', ls = '--', lw = 1)
plt.plot(trash2,z_norm, 'b')



sal_norm[9][:] = trash1
turb_norm[9][:] = trash2
cla_norm[9][:] = trash3
od_norm[9][:] = trash4
temp_norm[9][:] = trash5
dens_norm[9][:] = trash6

# %%
# print(np.nanmax(data['dados_ctd'][21][1][]),z_norm[16])

trash1 = np.interp(z_norm, data['dados_ctd'][21][1][1444:1469], data['dados_ctd'][21][3][1444:1469])
trash2 = np.interp(z_norm, data['dados_ctd'][21][1][1444:1469], data['dados_ctd'][21][5][1444:1469])
trash3 = np.interp(z_norm, data['dados_ctd'][21][1][1444:1469], data['dados_ctd'][21][4][1444:1469])
trash4 = np.interp(z_norm, data['dados_ctd'][21][1][1444:1469], data['dados_ctd'][21][6][1444:1469])
trash5 = np.interp(z_norm, data['dados_ctd'][21][1][1444:1469], data['dados_ctd'][21][2][1444:1469])
trash6 = np.interp(z_norm, data['dados_ctd'][21][1][1444:1469], data['dados_ctd'][21][7][1444:1469])


trash1[49:] = np.nan
trash2[49:] = np.nan
trash3[49:] = np.nan
trash4[49:] = np.nan
trash5[49:] = np.nan
trash6[49:] = np.nan

plt.title('profile 11')
plt.plot( data['dados_ctd'][21][5][1444:1469], data['dados_ctd'][21][1][1444:1469], 'r')
plt.plot( data['dados_ctd'][21][5][1444:1490], data['dados_ctd'][21][1][1444:1490], 'k', ls = '--', lw = 1)
plt.plot(trash2,z_norm, 'b')



sal_norm[10][:] = trash1
turb_norm[10][:] = trash2
cla_norm[10][:] = trash3
od_norm[10][:] = trash4
temp_norm[10][:] = trash5
dens_norm[10][:] = trash6

# %%
# print(np.nanmax(data['dados_ctd'][21][1][]),z_norm[16])

trash1 = np.interp(z_norm, data['dados_ctd'][21][1][1510:1540], data['dados_ctd'][21][3][1510:1540])
trash2 = np.interp(z_norm, data['dados_ctd'][21][1][1510:1540], data['dados_ctd'][21][5][1510:1540])
trash3 = np.interp(z_norm, data['dados_ctd'][21][1][1510:1540], data['dados_ctd'][21][4][1510:1540])
trash4 = np.interp(z_norm, data['dados_ctd'][21][1][1510:1540], data['dados_ctd'][21][6][1510:1540])
trash5 = np.interp(z_norm, data['dados_ctd'][21][1][1510:1540], data['dados_ctd'][21][2][1510:1540])
trash6 = np.interp(z_norm, data['dados_ctd'][21][1][1510:1540], data['dados_ctd'][21][7][1510:1540])


trash1[39:] = np.nan
trash2[39:] = np.nan
trash3[39:] = np.nan
trash4[39:] = np.nan
trash5[39:] = np.nan
trash6[39:] = np.nan

plt.title('profile 12')
plt.plot( data['dados_ctd'][21][5][1510:1540], data['dados_ctd'][21][1][1510:1540], 'r')
plt.plot( data['dados_ctd'][21][5][1510:1550], data['dados_ctd'][21][1][1510:1550], 'k', ls = '--', lw = 1)
plt.plot(trash2,z_norm, 'b')



sal_norm[11][:] = trash1
turb_norm[11][:] = trash2
cla_norm[11][:] = trash3
od_norm[11][:] = trash4
temp_norm[11][:] = trash5
dens_norm[11][:] = trash6

# %%
ssc = 8.215 + 0.455*turb_norm#-1.05+1.03*turb_norm

fig, ax = plt.subplots(figsize=(16,4), dpi = 100)

q = ax.contourf(ctd_cumdist, -z_norm, np.log(ssc.T),  np.arange(np.nanmin(np.log(ssc.T)), np.nanmax(np.log(ssc.T)), 0.01),cmap=plt.cm.jet)
plt.colorbar(q)

# %%
ssc = 8.215 + 0.455*turb_norm#-1.05+1.03*turb_norm

fig, ax = plt.subplots(figsize=(16,4), dpi = 100)

q = ax.contourf(ctd_cumdist, -z_norm, ssc.T, cmap=plt.cm.jet)
plt.colorbar(q)

# %%
fig, ax = plt.subplots(figsize=(16,4), dpi = 100)

q = ax.contourf(ctd_cumdist, -z_norm, sal_norm.T, np.arange(np.nanmin(sal_norm),np.nanmax(sal_norm)+0.1,0.1), cmap=plt.cm.jet)
plt.colorbar(q)

# %%
fig, ax = plt.subplots(figsize=(16,4), dpi = 100)

q = ax.contourf(ctd_cumdist, -z_norm, np.log(turb_norm.T),  cmap=plt.cm.jet)
plt.colorbar(q)

# %%
ssc = 8.215 + 0.455*turb_norm#-1.05+1.03*turb_norm

fig, ax = plt.subplots(figsize=(16,4), dpi = 100)

q = ax.contourf(ctd_cumdist, -z_norm, np.log(ssc.T), np.arange(np.nanmin(np.log(ssc.T)),np.nanmax(np.log(ssc.T))+0.05,0.05),  cmap=plt.cm.jet)
plt.colorbar(q)

# %%
fig, ax = plt.subplots(figsize=(16,4), dpi = 100)

q = ax.contourf(ctd_cumdist, -z_norm, (dens_norm.T), (np.arange(np.nanmin(dens_norm),np.nanmax(dens_norm)+1,1)),  cmap=plt.cm.jet)
plt.colorbar(q)

# %%
dados_ctd5 = np.zeros((10,165,12))
dados_ctd5[0] = sal_norm.T
dados_ctd5[1] = turb_norm.T
dados_ctd5[2] = ssc.T
dados_ctd5[3] = cla_norm.T
dados_ctd5[4] = od_norm.T
dados_ctd5[5] = temp_norm.T
dados_ctd5[6] = dens_norm.T
dados_ctd5[7] = ctd_cumdist
dados_ctd5[8] = ctd_loc[:,0]
dados_ctd5[9] = ctd_loc[:,1]

with open('C:\\Users\\simcosta\\Documents\\doc\\Campo_2023\\Campo_2023\\Processados\\CTD5_REV.pkl', 'wb') as file:
    pickle.dump(dados_ctd5, file)

# %%
#
