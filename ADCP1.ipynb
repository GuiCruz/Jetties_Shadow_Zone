# %%
import numpy as np
import matplotlib.pyplot as plt
import datetime
from scipy import signal
from scipy.fft import fft, fftfreq, ifft, next_fast_len
import matplotlib.colors as colors
import matplotlib.dates as mdates
import rasterio
import pickle
from sklearn.decomposition import PCA

# %%
# Definir o diretório raiz e o prefixo do nome do arquivo
roots = "C:\\Users\\simcosta\\Documents\\doc\\Campo_2023\\Campo_2023\\dados_brutos\\ADCP1_8528\\"
names = "gui01."
# Definir as extensões dos arquivos a serem lidos
extensions = ['sen', 'v1', 'v2', 'v3', 'a1', 'a2', 'a3']
# Ler cada arquivo e armazenar os dados
for ext in extensions:
    arq = np.loadtxt (roots + names + ext)
    globals()[ext] = arq

# %%
time = []
time_II = []
db = sen[:,13] #pressao
depth = ((db*10000)/(1021.32*9.79499))

for i in range(len(sen[:,2])):
    tsh_tempo = datetime.datetime(int(sen[i,2]),
                                 int(sen[i,0]),
                                 int(sen[i,1]),
                                 int(sen[i,3]),
                                 int(sen[i,4]),
                                 int(sen[i,5]))
    tsh_tempo_II = datetime.datetime.timestamp(tsh_tempo)# Converti pra timestamp pra poder interpolar.
    time.append(tsh_tempo)
    time_II.append(tsh_tempo_II)

# %%
print(time[2], time[62])
# Out:
# 2023-11-28 06:20:00 2023-11-28 16:20:00

# %%
m=2
n=62
fig, ax = plt.subplots(figsize=(14,4), dpi = 300)
ax.scatter(time[m:n], depth[m:n], color  = 'b', linewidth = 0.5, s=5)
ax.plot(time[m:n], depth[m:n], color  = 'b', linewidth = 0.5)
plt.title("Profundidade X Tempo - Ponto 1- Aquadopp 2MHz - 8528", fontsize=10)
ax.set_ylabel('Profundidade (m)')
ax.set_xlim(np.nanmin(time[m:n]), np.nanmax(time[m:n]))
ax.axvline(x = time[61], color='r')

# %%
m=2
n=62
z = np.arange(0.3, 9.3, 0.1)
amp = (a1[m:n,:] + a2[m:n,:] + a3[m:n,:])/3

# %%
m=2
n=62
fig, ax = plt.subplots(figsize=(10,2), dpi = 100)
plt.title("Amplitude Ponto 2- Aquadopp 1MHz - 5364", fontsize=10)
ax.contourf(time[m:n], z, amp.T)
ax.axhline(y=z[53], color='r', linestyle='--')

# %%
fig, ax = plt.subplots(figsize=(2,4), dpi = 100)
ax.plot(np.nanmean(amp, axis = 0),z)
ax.plot(np.nanmean(amp, axis = 0),z)
plt.axhline(y=z[54], color='r', linestyle='--')
plt.title("Ponto 1- Aquadopp 2MHz - 8528", fontsize=10)

plt.ylabel('Profundidade (m)')
plt.xlabel("Amplitude (dB)")
# Out:
# Text(0.5, 0, 'Amplitude (dB)')

# %%
amp_cut = np.delete(amp, slice(54,90), axis = 1)
z_cut = np.delete(z, slice(54,90), axis = 0)

v1_cut = np.delete(v1, slice(54,90), axis=1)
v2_cut = np.delete(v2, slice(54,90), axis=1)
v3_cut = np.delete(v3, slice(54,90), axis=1)
a1_cut = np.delete(a1, slice(54,90), axis=1)
a2_cut = np.delete(a2, slice(54,90), axis=1)
a3_cut = np.delete(a3, slice(54,90), axis=1)

# %%
m=2
n=62
fig, ax = plt.subplots(figsize=(10,2), dpi = 100)
plt.title("Profundidade X Tempo - Ponto 1- Aquadopp 2MHz - 8528", fontsize=10)
ax.contourf(time[m:n], z_cut, amp_cut[:,:].T)

# %%
m=2
n=62
#Comparando os dados de vel. brutos com os dados rotacionados. 
fig, ax = plt.subplots(figsize=(5,5), dpi = 80)
n = np.linspace(0, 2*np.pi, 100)
circ_x = np.sin(n)
circ_y = np.cos(n)
ax.plot(circ_x, circ_y,'k')
ax.plot([0,0], [-1.1, 1.1], 'k')
ax.plot([-1.1, 1.1], [0, 0], 'k')
ax.axis('equal')
plt.title("Componente U e V de vel. - Ponto1 ", fontsize=10)
ax.scatter(v1_cut[2:62,:],v2_cut[2:62,:],c = 'r', s = 0.5, label = 'Com rotacao')

# %%
# Supondo que v1_cut e v2_cut são numpy arrays
v1 = v1_cut[2:62,:].flatten()  # Ajuste os índices conforme necessário
v2 = v2_cut[2:62,:].flatten()  # Ajuste os índices conforme necessário

# Organizando os dados para a PCA
data = np.vstack((v1, v2)).T

# Aplicando PCA
pca = PCA(n_components=2)
pca.fit(data)
components = pca.components_

# Componentes principais
pc1 = components[0]
pc2 = components[1]

# Calculando o ângulo entre o primeiro componente principal e o norte verdadeiro (eixo y)
angle_with_north = np.arctan2(pc1[1], pc1[0])  # Em radianos
angle_with_north_deg = np.degrees(angle_with_north) + 90  # Convertendo para graus

print(f"Ângulo com o norte verdadeiro: {angle_with_north_deg:.2f} graus")

# Plotando os dados
plt.scatter(v1, v2, c='r', s=0.5, label='Com rotacao')

# Plotando os componentes principais
origin = [0], [0]  # origem
plt.quiver(*origin, *pc1, color='b', scale=3, label='PC1')
plt.quiver(*origin, *pc2, color='g', scale=3, label='PC2')

plt.xlabel('Componente U')
plt.ylabel('Componente V')
plt.legend()
plt.title('PCA das componentes U e V')
plt.grid(True)
plt.show()
# Out:
# Ângulo com o norte verdadeiro: 105.77 graus

# %%
#Rotacionando os dados de vel. em 29 graus.
M = np.sqrt(v1_cut[2:62,:]**2+v2_cut[2:62,:]**2)
UV_dir = np.arctan2(v2_cut[2:62,:]/M, v1_cut[2:62,:]/M) 
UV_dir_degrees = np.rad2deg(UV_dir)
UV_dir_degrees[UV_dir_degrees < 0] += 360   

U_spin = np.zeros((len(M), len(z_cut[:])))
V_spin = np.zeros((len(M), len(z_cut[:])))

for i in range(len(z_cut)):
    for j in range(len(M)):
        if (M[j,i] != 0):
            rot_ang = (UV_dir_degrees[j,i]+74.23)%360        
            V_spin[j,i] = M[j,i]*np.cos(np.radians(rot_ang))
            U_spin[j,i] = M[j,i]*np.sin(np.radians(rot_ang))

# %%
m=2
n=62
#Comparando os dados de vel. brutos com os dados rotacionados. 
fig, ax = plt.subplots(figsize=(5,5), dpi = 80)
n = np.linspace(0, 2*np.pi, 100)
circ_x = np.sin(n)
circ_y = np.cos(n)
ax.plot(circ_x, circ_y,'k')
ax.plot([0,0], [-1.1, 1.1], 'k')
ax.plot([-1.1, 1.1], [0, 0], 'k')
ax.axis('equal')
plt.title("Componente U e V de vel. - Ponto1 ", fontsize=10)
ax.scatter(v1_cut[2:62,:],v2_cut[2:62,:],c = 'r', s = 1, label = 'Com rotacao')
ax.scatter(V_spin,U_spin,c = 'k', s = 0.5, label = 'Com rotacao')

# %%
m=2
n=62
divnorm = colors.TwoSlopeNorm(vmin = np.min(V_spin),vcenter = 0, vmax = np.max(V_spin))
myFmt = mdates.DateFormatter('%H:%M')

fig, ax = plt.subplots(figsize=(10,2), dpi = 100)
plt.title("v1 filtrada - Ponto 1- Aquadopp 2MHz - 8528", fontsize=10)
q = ax.contourf(time[m:n], z_cut, V_spin.T, np.round(np.linspace(np.min(V_spin), np.max(V_spin), 20),2), cmap=plt.cm.bwr, norm = divnorm)
ax.contour(time[m:n], z_cut, V_spin.T, levels = [0], colors ='k', linewidths = 0.5, norm = divnorm)
ax.xaxis.set_major_formatter(myFmt)
plt.colorbar(q)

# %%
m=2
n=62
divnorm = colors.TwoSlopeNorm(vmin = np.min(U_spin),vcenter = 0, vmax = np.max(U_spin))
myFmt = mdates.DateFormatter('%H:%M')

fig, ax = plt.subplots(figsize=(10,2), dpi = 100)
plt.title("v1 filtrada - Ponto 1- Aquadopp 2MHz - 8528", fontsize=10)
q = ax.contourf(time[m:n], z_cut, U_spin.T, np.round(np.linspace(np.min(U_spin), np.max(U_spin), 20),2), cmap=plt.cm.bwr, norm = divnorm)
ax.contour(time[m:n], z_cut, U_spin.T, levels = [0], colors ='k', linewidths = 0.5, norm = divnorm)
ax.xaxis.set_major_formatter(myFmt)
plt.colorbar(q)

# %%
z_03 = np.arange(0.4, 5.8, 0.3)

U_fft03 = np.empty((60, 18))
for i in range(U_spin.shape[0]):
    for j in range(0, U_spin.shape[1], 3):
        U_fft03[i, j//3] = np.nanmean(U_spin[i, j:j+3])

V_fft03 = np.empty((60, 18))
for i in range(V_spin.shape[0]):
    for j in range(0, V_spin.shape[1], 3):
        V_fft03[i, j//3] = np.nanmean(V_spin[i, j:j+3])

# %%
m=2
n=62
fig, ax = plt.subplots(figsize=(10,2), dpi = 100)
divnorm = colors.TwoSlopeNorm(vmin = np.min(U_fft03),vcenter = 0, vmax = np.max(U_fft03))
myFmt = mdates.DateFormatter('%H:%M')

plt.title("v2 filtrada - Ponto 1- Aquadopp 2MHz - 8528", fontsize=10)
q = ax.contourf(time[m:n], z_03, U_fft03.T,  np.round(np.linspace(np.min(U_fft03), np.max(U_fft03), 20),2), cmap=plt.cm.bwr, norm = divnorm)
ax.contour(time[m:n], z_03, U_fft03.T, levels = [0], colors ='k', linewidths = 0.5, norm = divnorm)
ax.xaxis.set_major_formatter(myFmt)
plt.colorbar(q)

# %%
m=2
n=62
divnorm = colors.TwoSlopeNorm(vmin = np.min(V_fft03),vcenter = 0, vmax = np.max(V_fft03))
myFmt = mdates.DateFormatter('%H:%M')

fig, ax = plt.subplots(figsize=(10,2), dpi = 100)
plt.title("v1 filtrada - Ponto 1- Aquadopp 2MHz - 8528", fontsize=10)
q = ax.contourf(time[m:n], z_03, V_fft03.T, np.round(np.linspace(np.min(V_fft03), np.max(V_fft03), 20),2), cmap=plt.cm.bwr, norm = divnorm)
ax.contour(time[m:n], z_03, V_fft03.T, levels = [0], colors ='k', linewidths = 0.5, norm = divnorm)
ax.xaxis.set_major_formatter(myFmt)
plt.colorbar(q)

# %%
m=2
n=62
dados_adcp1 = np.zeros((3,60,18))
dados_adcp1[0] = U_fft03
dados_adcp1[1] = V_fft03




with open('C:\\Users\\simcosta\\Documents\\doc\\Campo_2023\\Campo_2023\\Processados\\ADCP1_UVSSC_REV.pkl', 'wb') as file:
    pickle.dump(dados_adcp1, file)

with open('C:\\Users\\simcosta\\Documents\\doc\\Campo_2023\\Campo_2023\\Processados\\ADCP1_depth_REV.pkl', 'wb') as file:
    pickle.dump(depth[m:n], file)
    
with open('C:\\Users\\simcosta\\Documents\\doc\\Campo_2023\\Campo_2023\\Processados\\ADCP1_time_REV.pkl', 'wb') as file:
    pickle.dump(time[m:n], file)
